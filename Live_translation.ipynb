# %%
# !pip install -r Realtime-translation/requirements.txt
# !mkdir RealtimeTranlator
# !cp -r Realtime-translation RealtimeTranlator
# !touch RealtimeTranlator/__init__

from RealtimeTranlator.GradioApp import launch_app

launch_app()
